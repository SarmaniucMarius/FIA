# %%
import pandas
from sklearn import datasets, linear_model, preprocessing

f = pandas.read_csv("apartmentComplexData.txt", names=["IGNORED1", "IGNORED2", "complexAge", "totalRooms", "totalBedrooms", "complexInhabitants", "apartmentsNr", "IGNORED8", "medianCompexValue"])
f = f.drop(["IGNORED1", "IGNORED2", "IGNORED8"], axis=1)
# x = f['complexInhabitants'].values.reshape(-1, 1)
# f['complexInhabitants'] = preprocessing.normalize(x, norm='l2')
print(f.shape)
print(f.info())
f.head(3)
# Out:
# (20640, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   complexAge          20640 non-null  float64
#  1   totalRooms          20640 non-null  float64
#  2   totalBedrooms       20640 non-null  float64
#  3   complexInhabitants  20640 non-null  float64
#  4   apartmentsNr        20640 non-null  float64
#  5   medianCompexValue   20640 non-null  float64
# dtypes: float64(6)
# memory usage: 967.6 KB
# None
#    complexAge  totalRooms  ...  apartmentsNr  medianCompexValue
# 0        41.0       880.0  ...         126.0           452600.0
# 1        21.0      7099.0  ...        1138.0           358500.0
# 2        52.0      1467.0  ...         177.0           352100.0
#
# [3 rows x 6 columns]

# %%
f.describe()
# Out:
#          complexAge    totalRooms  ...  apartmentsNr  medianCompexValue
# count  20640.000000  20640.000000  ...  20640.000000       20640.000000
# mean      28.639486   2635.763081  ...    499.539680      206857.900242
# std       12.585558   2181.615252  ...    382.329753      115395.780951
# min        1.000000      2.000000  ...      1.000000       14999.000000
# 25%       18.000000   1447.750000  ...    280.000000      119600.000000
# 50%       29.000000   2127.000000  ...    409.000000      179700.000000
# 75%       37.000000   3148.000000  ...    605.000000      264725.000000
# max       52.000000  39320.000000  ...   6082.000000      500001.000000
#
# [8 rows x 6 columns]

# %%
f.duplicated().values.any()
# Out:
# False

# %%
f.isnull().values.any()
# Out:
# False

# %%
f.boxplot(column='complexAge')

# %%
f.boxplot(column='totalRooms')

# %%
f.boxplot(column='totalBedrooms')

# %%
f.boxplot(column='complexInhabitants')

# %%
f.boxplot(column='apartmentsNr')

# %%
f.boxplot(column='medianCompexValue')

# %%
Q1 = f.quantile(0.25)
Q3 = f.quantile(0.75)
IQR = Q3 - Q1
f_out = f[(f > (Q1 - 1.5 * IQR)) & (f < (Q3 + 1.5 * IQR))]
f = f_out.dropna()
f
# Out:
#        complexAge  totalRooms  ...  apartmentsNr  medianCompexValue
# 0            41.0       880.0  ...         126.0           452600.0
# 2            52.0      1467.0  ...         177.0           352100.0
# 3            52.0      1274.0  ...         219.0           341300.0
# 4            52.0      1627.0  ...         259.0           342200.0
# 5            52.0       919.0  ...         193.0           269700.0
# ...           ...         ...  ...           ...                ...
# 20635        25.0      1665.0  ...         330.0            78100.0
# 20636        18.0       697.0  ...         114.0            77100.0
# 20637        17.0      2254.0  ...         433.0            92300.0
# 20638        18.0      1860.0  ...         349.0            84700.0
# 20639        16.0      2785.0  ...         530.0            89400.0
#
# [17816 rows x 6 columns]

# %%
f.boxplot(column='complexAge')

# %%
f.boxplot(column='totalRooms')

# %%
f.boxplot(column='totalBedrooms')

# %%
f.boxplot(column='complexInhabitants')

# %%
f.boxplot(column='apartmentsNr')

# %%
f.boxplot(column='medianCompexValue')

# %%
f.plot.scatter(x='complexAge', y='medianCompexValue')

# %%
f.plot.scatter(x='totalRooms', y='medianCompexValue')

# %%
f.plot.scatter(x='totalBedrooms', y='medianCompexValue')

# %%
f.plot.scatter(x='complexInhabitants', y='medianCompexValue')

# %%
f.plot.scatter(x='apartmentsNr', y='medianCompexValue')
